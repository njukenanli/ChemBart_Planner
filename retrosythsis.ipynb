# %%
# %load_ext autoreload
# %autoreload 2

# %%
config = \
{
            "save_path": 'wangguoqiang/shihua250807_mol5/skip_roundback_beam_test' ,
            "bascic_mol": "CB_Planner/data/basic_mol.json",
            "chembart_path":'/home/zhangyijian/ChemBart/v2/ChemBart_model/ChemBart_FULL_4.pth',
            "rl_path":'/home/zhangyijian/ChemBart/CB_Planner/CB_Planner/functions/ChemBart/model/CB_MCTS.pth',
            "ty_path":'/home/zhangyijian/ChemBart/CB_Planner/CB_Planner/functions/ChemBart/model/temp_yield_bart.pth', 
            # params for supervision
            "getdata": {
                "train": False,  # retain search data for RL training or not
                "max_train_data_num": 5000,  # if retain training data, at most how many data should be retained.
            },

            # params for computing
            "mcts": {
                #"mcts_times": 50, # iteration time per step
                "mcts_times": 20,
                "max_route_len": 8, # the max length of the route designed, if the program exceeds the limit but still haven't finished, return failed.
                "max_search_depth": 8, # the max depth of DFS in MCTS
                "temp_coef" : 1.0, # the temperature coefficient of policy 
                "Cpuct" : 10.0, # the Cpuct coeeficient in mcts
                "update_method" : 'avg', # or 'min'
                "debug": False, # print informantion when MCTS
            },

            "nn":{
                "gen_dev": "cuda:2", # device to load generation model (pre-trained model)
                "agt_dev": "cuda:2", # device to load agent model (pre-trained model)
                "pro_dev": "cuda:2", # device to load product (round trip) model (pre-trained model)
                "rl_dev": "cuda:2", # device to load RL model (fine-tuned model)
                "temp_yield_dev": "cuda:2", # device to load model for temperature and yield prediction (fine-tuned model)
                #"choiceperstep": 50, # num of choices generated in each node in the tree.
                "sampling_method": 'beam', #'top_k' / 'top_p' / 'beam'
                "topk": 10,
                "topp": 0.9,
                "num_samples": 10,
                #"temperature":1.0
            },

            # params for computing resources. If the cuda returns error or the gpu just does not work, reduce this params!
            "parallel":{
                "process_parallel": False,
                "pool_size": 3, # num of molecules (processes) that can be solved at the same time. Each process requires one cpu (so do not exceed num of cpus) and part of the gpu memory (so usually this param is much smaller than num of cpus).
                "semaphore_per_model": 3, # num of processes that can call a model at the same time, linited by the gpu memory.
            }
}

# %%
tasklist_1 = [
            ('Clc(cc1)cc2c1oc3c2c(Br)ccc3', 5),                    
            #('Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl', 10),
            #('COc1cccc(Br)c1-c1cc(Cl)ccc1Cl', 10),
            ]

# %%
from CB_Planner.board import CB_Planner
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

print('program strated~')
print('total data',len(tasklist_1))
planner = CB_Planner(config)
# Out:
# program strated~
# total data 1
# 成功创建保存目录：wangguoqiang/shihua250807_mol5/skip_roundback_beam_test/

# %%
ans = planner.plan(tasklist_1)
# Out:
# [DFS] Depth=3 | Node: COc1cccc(N)c1-c1cc(Cl)ccc1Cl | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   COc1cccc([N+](=O)[O-])c1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       1   COc1cccc([N+](=O)[O-])c1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       2   COc1cccc(N)c1B(O)O.Clc1ccc(Cl)c(Br)c1 0.100  0    0.000  1.000  1.000
#       3   COc1cccc(N)c1B(O)O.Clc1ccc(Cl)c(I)c1 0.100  0    0.000  1.000  1.000
#       4   (cycle) Nc1cccc(O)c1-c1cc(Cl)ccc1Cl.O=C([O-])[O-] 0.100  0    0.000  -      -
#       5   COc1cccc(N)c1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       6   COc1cccc(NC(C)=O)c1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       7   COc1cccc([N+](=O)[O-])c1B(O)O.Clc1ccc(Cl)c(Br)c1 0.100  0    0.000  1.000  1.000
#       8   (cycle) Nc1cccc(O)c1-c1cc(Cl)ccc1Cl.O=C([O-])O 0.100  0    0.000  -      -
#       9   COc1cccc([N+](=O)[O-])c1-c1cc(Cl)ccc1F 0.100  0    0.000  1.000  1.000
# mol skip round back test!
#
# [DFS] Depth=4 | Node: COc1cccc([N+](=O)[O-])c1-c1cc(Cl)ccc1Cl | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   COc1cccc([N+](=O)[O-])c1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       1   COc1ccccc1-c1cc(Cl)ccc1Cl.O=[N+]([O-])O 0.100  0    0.000  1.000  1.000
#       2   COc1cccc([N+](=O)[O-])c1Cl.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       3   COc1ccccc1[N+](=O)[O-].OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       4   COc1cccc([N+](=O)[O-])c1Br.Clc1ccc(Cl)cc1 0.100  0    0.000  1.000  1.000
#       5   COc1ccccc1B(O)O.O=[N+]([O-])c1cccc(Cl)c1Br 0.100  0    0.000  1.000  1.000
#       6   COc1ccccc1B(O)O.O=[N+]([O-])c1ccc(Cl)c(Br)c1 0.100  0    0.000  1.000  1.000
#       7   COc1ccccc1B(O)O.O=[N+]([O-])c1cccc(Cl)c1Cl 0.100  0    0.000  1.000  1.000
#       8   COc1ccccc1B(O)O.O=[N+]([O-])c1ccc(Cl)c(Cl)c1 0.100  0    0.000  1.000  1.000
#       9   COc1cccc([N+](=O)[O-])c1B(O)O.Clc1ccc(Cl)cc1 0.100  0    0.000  1.000  1.000
#         [EVAL] COc1cccc([N+](=O)[O-])c1Br → is_end=True → V=1.0
#         [EVAL] OB(O)c1cc(Cl)ccc1Cl → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 4 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 7
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  0.980  1.980
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  1    1.000  1.470  2.470
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.470  2.470
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.470  2.470
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.470  2.470
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  0    0.000  2.940  2.940
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  0    0.000  2.940  2.940
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  0    0.000  2.940  2.940
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  0    0.000  2.940  2.940
#         [EVAL] [Br-] → is_end=True → V=1.0
#
# [DFS] Depth=2 | Node: Oc1ccccc1-c1cc(Cl)ccc1Cl | Total visits: 3
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.100  2    1.000  0.577  1.577
#       1   COc1ccccc1-c1cc(Cl)ccc1Cl      0.100  0    0.000  1.732  1.732
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1I 0.100  0    0.000  1.732  1.732
#       3   CC(=O)Oc1ccccc1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.732  1.732
#       4   Clc1ccc(Cl)c(Br)c1.OB(O)c1ccccc1O 0.100  0    0.000  1.732  1.732
#       5   OB(O)c1ccccc1O.Oc1ccc(Cl)cc1I  0.100  0    0.000  1.732  1.732
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1  0.100  0    0.000  1.732  1.732
#       7   OB(O)c1ccccc1O.Oc1ccc(Cl)cc1Br 0.100  0    0.000  1.732  1.732
#       8   OB(O)c1ccccc1O.Oc1ccccc1Br     0.100  0    0.000  1.732  1.732
#       9   OB(O)c1ccccc1O.Oc1ccccc1I      0.100  0    0.000  1.732  1.732
# mol skip round back test!
#
# [DFS] Depth=3 | Node: COc1ccccc1-c1cc(Cl)ccc1Cl | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   COc1ccccc1B(O)O.Clc1ccc(Cl)c(Br)c1 0.143  0    0.000  1.429  1.429
#       1   COc1ccccc1B(O)O.Clc1ccc(Cl)c(I)c1 0.143  0    0.000  1.429  1.429
#       2   COc1ccccc1Br.OB(O)c1cc(Cl)ccc1Cl 0.143  0    0.000  1.429  1.429
#       3   COc1ccccc1I.OB(O)c1cc(Cl)ccc1Cl 0.143  0    0.000  1.429  1.429
#       4   COc1ccccc1B(O)O.Fc1cc(Cl)ccc1Cl 0.143  0    0.000  1.429  1.429
#       5   Clc1ccc(Cl)c(I)c1.OB(O)c1ccccc1O 0.143  0    0.000  1.429  1.429
#       6   COc1ccccc1Br.Clc1ccc(Cl)c(I)c1 0.143  0    0.000  1.429  1.429
#         [EVAL] COc1ccccc1B(O)O → is_end=True → V=1.0
#         [EVAL] Clc1ccc(Cl)c(Br)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 1 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 5 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 8
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.048  2.048
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  1    1.000  1.571  2.571
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.571  2.571
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.571  2.571
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.571  2.571
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  1    1.000  1.571  2.571
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  0    0.000  3.143  3.143
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  0    0.000  3.143  3.143
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  0    0.000  3.143  3.143
#         [EVAL] OB(O)c1cc(Cl)ccc1Cl → is_end=True → V=1.0
#         [EVAL] Oc1ccccc1Br → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 6 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 9
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.111  2.111
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  1    1.000  1.667  2.667
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.667  2.667
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.667  2.667
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.667  2.667
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  1    1.000  1.667  2.667
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  1    1.000  1.667  2.667
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  0    0.000  3.333  3.333
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  0    0.000  3.333  3.333
#         [EVAL] O → is_end=True → V=1.0
# mol skip round back test!
#
# [DFS] Depth=2 | Node: Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   O=[N+]([O-])c1cccc(Br)c1-c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       1   BrBr.Nc1ccccc1-c1cc(Cl)ccc1Cl  0.111  0    0.000  1.111  1.111
#       2   Nc1cccc(Br)c1I.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       3   Nc1cccc(Br)c1Br.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       4   Nc1cccc(Br)c1B(O)O.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       5   CC(=O)Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       6   Nc1ccccc1Br.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.111  1.111
#       7   Nc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  0    0.000  1.111  1.111
#       8   Nc1ccccc1-c1cc(Cl)ccc1Cl.O=[N+]([O-])O 0.111  0    0.000  1.111  1.111
# mol skip round back test!
#
# [DFS] Depth=3 | Node: O=[N+]([O-])c1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   Clc1ccc(Cl)c(I)c1.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#       1   BrBr.O=[N+]([O-])c1ccccc1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       2   O=[N+]([O-])c1ccccc1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.000  1.000
#       3   BrBr.O=[N+]([O-])c1ccccc1-c1ccccc1Cl 0.100  0    0.000  1.000  1.000
#       4   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#       5   Clc1ccc(Cl)cc1.O=[N+]([O-])c1cccc(Br)c1Br 0.100  0    0.000  1.000  1.000
#       6   Clc1ccc(Cl)cc1.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#       7   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1ccccc1F 0.100  0    0.000  1.000  1.000
#       8   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1ccccc1Br 0.100  0    0.000  1.000  1.000
#       9   O=C1CCC(=O)N1Br.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#         [EVAL] Clc1ccc(Cl)c(I)c1 → is_end=True → V=1.0
#         [EVAL] O=[N+]([O-])c1cccc(Br)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 7 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 10
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.171  2.171
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  1    1.000  1.757  2.757
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.757  2.757
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.757  2.757
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.757  2.757
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  1    1.000  1.757  2.757
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  1    1.000  1.757  2.757
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  1    1.000  1.757  2.757
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  0    0.000  3.514  3.514
#
# [DFS] Depth=2 | Node: Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 2
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   O=[N+]([O-])c1cccc(Br)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  0.786  1.786
#       1   BrBr.Nc1ccccc1-c1cc(Cl)ccc1Cl  0.111  0    0.000  1.571  1.571
#       2   Nc1cccc(Br)c1I.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.571  1.571
#       3   Nc1cccc(Br)c1Br.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.571  1.571
#       4   Nc1cccc(Br)c1B(O)O.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.571  1.571
#       5   CC(=O)Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl 0.111  0    0.000  1.571  1.571
#       6   Nc1ccccc1Br.OB(O)c1cc(Cl)ccc1Cl 0.111  0    0.000  1.571  1.571
#       7   Nc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  0    0.000  1.571  1.571
#       8   Nc1ccccc1-c1cc(Cl)ccc1Cl.O=[N+]([O-])O 0.111  0    0.000  1.571  1.571
#
# [DFS] Depth=3 | Node: O=[N+]([O-])c1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 2
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   Clc1ccc(Cl)c(I)c1.O=[N+]([O-])c1cccc(Br)c1 0.100  1    1.000  0.707  1.707
#       1   BrBr.O=[N+]([O-])c1ccccc1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.414  1.414
#       2   O=[N+]([O-])c1ccccc1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.414  1.414
#       3   BrBr.O=[N+]([O-])c1ccccc1-c1ccccc1Cl 0.100  0    0.000  1.414  1.414
#       4   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.414  1.414
#       5   Clc1ccc(Cl)cc1.O=[N+]([O-])c1cccc(Br)c1Br 0.100  0    0.000  1.414  1.414
#       6   Clc1ccc(Cl)cc1.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.414  1.414
#       7   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1ccccc1F 0.100  0    0.000  1.414  1.414
#       8   Clc1ccc(Cl)c(Br)c1.O=[N+]([O-])c1ccccc1Br 0.100  0    0.000  1.414  1.414
#       9   O=C1CCC(=O)N1Br.O=[N+]([O-])c1cccc(Br)c1 0.100  0    0.000  1.414  1.414
#         [EVAL] Clc1ccc(Cl)c(I)c1 → is_end=True → V=1.0
#         [EVAL] O=[N+]([O-])c1cccc(Br)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 1.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 1.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 8 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 11
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.228  2.228
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  1    1.000  1.843  2.843
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.843  2.843
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.843  2.843
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.843  2.843
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  1    1.000  1.843  2.843
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  1    1.000  1.843  2.843
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  1    1.000  1.843  2.843
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  1    1.000  1.843  2.843
#
# [DFS] Depth=2 | Node: COc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 2
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   COc1cccc(Br)c1B(O)O.Clc1ccc(Cl)c(I)c1 0.100  1    1.000  0.707  1.707
#       1   COc1cccc(Br)c1I.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.414  1.414
#       2   COc1cccc(Br)c1Br.OB(O)c1cc(Cl)ccc1Cl 0.100  0    0.000  1.414  1.414
#       3   BrBr.COc1ccccc1-c1cc(Cl)ccc1Cl 0.100  0    0.000  1.414  1.414
#       4   COc1ccccc1B(O)O.Clc1ccc(Cl)c(I)c1 0.100  0    0.000  1.414  1.414
#       5   COc1cccc(Br)c1Br.Clc1ccc(Cl)c(I)c1 0.100  0    0.000  1.414  1.414
#       6   COc1ccccc1B(O)O.Clc1ccc(Cl)c(Br)c1 0.100  0    0.000  1.414  1.414
#       7   COc1ccccc1Br.Clc1ccc(Cl)c(I)c1 0.100  0    0.000  1.414  1.414
#       8   COc1cccc(Br)c1I.Clc1ccc(Cl)c(I)c1 0.100  0    0.000  1.414  1.414
#       9   COc1cccc(Br)c1Br.Clc1ccc(Cl)c(Br)c1 0.100  0    0.000  1.414  1.414
#         [EVAL] COc1cccc(Br)c1B(O)O → is_end=True → V=1.0
#         [EVAL] Clc1ccc(Cl)c(I)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 1.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 1 → N+1, V=1.000, Q: 1.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl | Total visits: 12
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   BrBr.Oc1ccccc1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.283  2.283
#       1   COc1cccc(Br)c1-c1cc(Cl)ccc1Cl  0.111  2    1.000  1.283  2.283
#       2   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br 0.111  1    1.000  1.925  2.925
#       3   OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1 0.111  1    1.000  1.925  2.925
#       4   Br.Nc1cccc(O)c1-c1cc(Cl)ccc1Cl 0.111  1    1.000  1.925  2.925
#       5   Oc1ccccc1-c1cc(Cl)ccc1Cl.[Br-] 0.111  1    1.000  1.925  2.925
#       6   OB(O)c1cc(Cl)ccc1Cl.Oc1ccccc1Br 0.111  1    1.000  1.925  2.925
#       7   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl.O 0.111  1    1.000  1.925  2.925
#       8   Nc1cccc(Br)c1-c1cc(Cl)ccc1Cl   0.111  1    1.000  1.925  2.925
#         [EVAL] OB(O)c1cc(Cl)ccc1Cl → is_end=True → V=1.0
#         [EVAL] Oc1cccc(Br)c1Br → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 2 → N+1, V=1.000, Q: 1.000 → 1.000
#
# [DFS_MAIN] MCTS completed for Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl (mcts_times=10)
#   Branch 0: N=  2 | Q=1.000 | P=0.111 | Policy=0.167
#   Branch 1: N=  2 | Q=1.000 | P=0.111 | Policy=0.167
#   Branch 2: N=  2 | Q=1.000 | P=0.111 | Policy=0.167
#   Branch 3: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#   Branch 4: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#   Branch 5: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#   Branch 6: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#   Branch 7: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#   Branch 8: N=  1 | Q=1.000 | P=0.111 | Policy=0.083
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 2
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  1    1.000  0.707  1.707
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  1.414  1.414
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  0    0.000  1.414  1.414
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  0    0.000  1.414  1.414
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  1.414  1.414
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  1.414  1.414
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  1.414  1.414
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  1.414  1.414
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  1.414  1.414
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  1.414  1.414
#         [EVAL] OB(O)c1cccc(Br)c1 → is_end=True → V=1.0
#         [EVAL] Oc1ccc(Cl)cc1I → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 0 → N+1, V=1.000, Q: 1.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 3
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.577  1.577
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  1.732  1.732
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  0    0.000  1.732  1.732
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  0    0.000  1.732  1.732
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  1.732  1.732
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  1.732  1.732
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  1.732  1.732
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  1.732  1.732
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  1.732  1.732
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  1.732  1.732
#         [EVAL] Brc1cccc(I)c1 → is_end=True → V=1.0
#         [EVAL] OB(O)c1cc(Cl)ccc1O → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 1 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 4
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.667  1.667
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  1    1.000  1.000  2.000
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  0    0.000  2.000  2.000
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  0    0.000  2.000  2.000
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  2.000  2.000
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  2.000  2.000
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  2.000  2.000
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  2.000  2.000
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  2.000  2.000
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  2.000  2.000
#         [EVAL] Brc1cccc(I)c1 → is_end=True → V=1.0
#         [EVAL] OB(O)c1cc(Cl)ccc1O → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 1 → N+1, V=1.000, Q: 1.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 5
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.745  1.745
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  0.745  1.745
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  0    0.000  2.236  2.236
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  0    0.000  2.236  2.236
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  2.236  2.236
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  2.236  2.236
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  2.236  2.236
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  2.236  2.236
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  2.236  2.236
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  2.236  2.236
#         [EVAL] COc1ccc(Cl)cc1-c1cccc(Br)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 2 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 6
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.816  1.816
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  0.816  1.816
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.225  2.225
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  0    0.000  2.449  2.449
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  2.449  2.449
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  2.449  2.449
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  2.449  2.449
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  2.449  2.449
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  2.449  2.449
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  2.449  2.449
#         [EVAL] OB(O)c1cccc(Br)c1 → is_end=True → V=1.0
#         [EVAL] Oc1ccc(Cl)cc1Br → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 3 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 7
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.882  1.882
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  0.882  1.882
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.323  2.323
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  1    1.000  1.323  2.323
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  0    0.000  2.646  2.646
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  2.646  2.646
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  2.646  2.646
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  2.646  2.646
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  2.646  2.646
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  2.646  2.646
#         [EVAL] Brc1cccc(Br)c1 → is_end=True → V=1.0
#         [EVAL] OB(O)c1cc(Cl)ccc1O → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 4 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 8
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  0.943  1.943
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  0.943  1.943
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.414  2.414
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  1    1.000  1.414  2.414
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  1    1.000  1.414  2.414
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  2.828  2.828
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  2.828  2.828
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  2.828  2.828
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  2.828  2.828
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  2.828  2.828
# mol skip round back test!
#
# [DFS] Depth=2 | Node: CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 1
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   (cycle) CC(=O)Cl.Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  -      -
#       1   CC(=O)Oc1ccc(Cl)cc1Br.OB(O)c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#       2   CC(=O)Oc1ccc(Cl)cc1I.OB(O)c1cccc(Br)c1 0.100  0    0.000  1.000  1.000
#       3   (cycle) CC(=O)[O-].Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  -      -
#       4   Brc1cccc(I)c1.CC(=O)Oc1ccc(Cl)cc1B(O)O 0.100  0    0.000  1.000  1.000
#       5   (cycle) CC(=O)O.Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  0    0.000  -      -
#       6   CC(=O)Oc1ccc(Cl)cc1B(O)O.Brc1cccc(I)c1 0.100  0    0.000  1.000  1.000
#       7   Brc1cccc(Br)c1.CC(=O)Oc1ccc(Cl)cc1B(O)O 0.100  0    0.000  1.000  1.000
#       8   Brc1cccc(I)c1.CC(=O)Oc1ccc(Cl)cc1I 0.100  0    0.000  1.000  1.000
#       9   CC(=O)Oc1ccc(Cl)cc1B(O)O.Ic1cccc(I)c1 0.100  0    0.000  1.000  1.000
#         [EVAL] CC(=O)Oc1ccc(Cl)cc1Br → is_end=True → V=1.0
#         [EVAL] OB(O)c1cccc(Br)c1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 1 → N+1, V=1.000, Q: 0.000 → 1.000
#         [BACKUP] Child V list: ['1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 5 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 9
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  1.000  2.000
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  1.000  2.000
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.500  2.500
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  1    1.000  1.500  2.500
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  1    1.000  1.500  2.500
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  1    1.000  1.500  2.500
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  0    0.000  3.000  3.000
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  3.000  3.000
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  3.000  3.000
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  3.000  3.000
#         [EVAL] OB(O)c1cccc(Br)c1 → is_end=True → V=1.0
#         [EVAL] Oc1ccc(Cl)cc1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 6 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 10
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  1.054  2.054
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  1.054  2.054
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.581  2.581
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  1    1.000  1.581  2.581
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  1    1.000  1.581  2.581
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  1    1.000  1.581  2.581
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  1    1.000  1.581  2.581
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  0    0.000  3.162  3.162
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  3.162  3.162
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  3.162  3.162
#         [EVAL] Brc1cccc(Br)c1 → is_end=True → V=1.0
#         [EVAL] Oc1ccc(Cl)cc1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 7 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS] Depth=1 | Node: Oc1ccc(Cl)cc1-c1cccc(Br)c1 | Total visits: 11
#       Idx Precursors                     P      N    Q      U      PUCT
#       ------------------------------------------------------------
#       0   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I 0.100  2    1.000  1.106  2.106
#       1   Brc1cccc(I)c1.OB(O)c1cc(Cl)ccc1O 0.100  2    1.000  1.106  2.106
#       2   COc1ccc(Cl)cc1-c1cccc(Br)c1    0.100  1    1.000  1.658  2.658
#       3   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1Br 0.100  1    1.000  1.658  2.658
#       4   Brc1cccc(Br)c1.OB(O)c1cc(Cl)ccc1O 0.100  1    1.000  1.658  2.658
#       5   CC(=O)Oc1ccc(Cl)cc1-c1cccc(Br)c1 0.100  1    1.000  1.658  2.658
#       6   OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1 0.100  1    1.000  1.658  2.658
#       7   Brc1cccc(Br)c1.Oc1ccc(Cl)cc1   0.100  1    1.000  1.658  2.658
#       8   Brc1cccc(I)c1.Oc1ccc(Cl)cc1    0.100  0    0.000  3.317  3.317
#       9   Brc1cccc(I)c1.Oc1ccc(Cl)cc1I   0.100  0    0.000  3.317  3.317
#         [EVAL] Brc1cccc(I)c1 → is_end=True → V=1.0
#         [EVAL] Oc1ccc(Cl)cc1 → is_end=True → V=1.0
#         [BACKUP] Child V list: ['1.000', '1.000'] → Parent V = 1.000
#       [BACKUP] Selected Branch 8 → N+1, V=1.000, Q: 0.000 → 1.000
#
# [DFS_MAIN] MCTS completed for Oc1ccc(Cl)cc1-c1cccc(Br)c1 (mcts_times=10)
#   Branch 0: N=  2 | Q=1.000 | P=0.100 | Policy=0.182
#   Branch 1: N=  2 | Q=1.000 | P=0.100 | Policy=0.182
#   Branch 2: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 3: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 4: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 5: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 6: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 7: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 8: N=  1 | Q=1.000 | P=0.100 | Policy=0.091
#   Branch 9: N=  0 | Q=0.000 | P=0.100 | Policy=0.000
# 成功保存训练数据到：/home/zhangyijian/ChemBart/CB_Planner/wangguoqiang/shihua250807_mol5/skip_roundback_beam_test/train_data.json
# fine-tuned model
# /home/zhangyijian/ChemBart/CB_Planner/CB_Planner/functions/ChemBart/model/temp_yield_bart.pth

# %%
ans
# Out:
# {'answer_0_Clc1ccc2oc3cccc(Br)c3c2c1_route_0': [{'success': 1,
#    'probability': 0.9999999500000025},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'BrBr': 'basic_molecule',
#     'Clc1ccc2oc3ccccc3c2c1': 'basic_molecule'}},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'reagents': 'CC(=O)[O-].[Na+].CC(=O)O',
#     'precursors': 'BrBr.Clc1ccc2oc3ccccc3c2c1',
#     'probability': 1.0,
#     'temperature': 56.2977180480957,
#     'yield': 78.48728942871094}}],
#  'answer_0_Clc1ccc2oc3cccc(Br)c3c2c1_route_1': [{'success': 1,
#    'probability': 0.9999997900000297},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'Brc1cccc2oc3ccccc3c12': 'basic_molecule',
#     'O=S(=O)(Cl)Cl': 'basic_molecule'}},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'reagents': 'ClC(Cl)Cl',
#     'precursors': 'Brc1cccc2oc3ccccc3c12.O=S(=O)(Cl)Cl',
#     'probability': 1.0,
#     'temperature': 46.56761169433594,
#     'yield': 80.06831359863281}}],
#  'answer_0_Clc1ccc2oc3cccc(Br)c3c2c1_route_2': [{'success': 1,
#    'probability': 0.4472135820835507},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'O=C(c1cc(Cl)ccc1Cl)c1c(O)cccc1Br': {'O=C(Cl)c1cc(Cl)ccc1Cl': 'basic_molecule',
#      'Oc1cccc(Br)c1': 'basic_molecule'}}},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'reagents': 'Cc1ccc(S(=O)(=O)O)cc1.Cc1ccccc1',
#     'precursors': 'O=C(c1cc(Cl)ccc1Cl)c1c(O)cccc1Br',
#     'probability': 0.2,
#     'temperature': 97.4853286743164,
#     'yield': 65.52511596679688},
#    'O=C(c1cc(Cl)ccc1Cl)c1c(O)cccc1Br': {'reagents': '[Al+3].[Cl-].[Cl-].[Cl-].ClCCl',
#     'precursors': 'O=C(Cl)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1',
#     'probability': 1.0,
#     'temperature': 15.091268539428711,
#     'yield': 70.20816040039062}}],
#  'answer_0_Clc1ccc2oc3cccc(Br)c3c2c1_route_3': [{'success': 1,
#    'probability': 0.44721355525073725},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl': {'OB(O)c1cc(Cl)ccc1Cl': 'basic_molecule',
#      'Oc1cccc(Br)c1Br': 'basic_molecule'}}},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'reagents': 'O=C([O-])[O-].[K+].[K+].CN(C)C=O',
#     'precursors': 'Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl',
#     'probability': 0.2,
#     'temperature': 97.75244903564453,
#     'yield': 67.94160461425781},
#    'Oc1cccc(Br)c1-c1cc(Cl)ccc1Cl': {'reagents': 'O=C([O-])[O-].[Na+].[Na+].c1ccc([P](c2ccccc2)(c2ccccc2)[Pd]([P](c2ccccc2)(c2ccccc2)c2ccccc2)([P](c2ccccc2)(c2ccccc2)c2ccccc2)[P](c2ccccc2)(c2ccccc2)c2ccccc2)cc1.COCCOC',
#     'precursors': 'OB(O)c1cc(Cl)ccc1Cl.Oc1cccc(Br)c1Br',
#     'probability': 1.0,
#     'temperature': 97.56013488769531,
#     'yield': 65.7907485961914}}],
#  'answer_0_Clc1ccc2oc3cccc(Br)c3c2c1_route_4': [{'success': 1,
#    'probability': 0.3162277486243117},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'Oc1ccc(Cl)cc1-c1cccc(Br)c1': {'OB(O)c1cccc(Br)c1': 'basic_molecule',
#      'Oc1ccc(Cl)cc1I': 'basic_molecule'}}},
#   {'Clc1ccc2oc3cccc(Br)c3c2c1': {'reagents': 'c1ccc(P(c2ccccc2)c2ccccc2)cc1.CC(C)OC(=O)/N=N/C(=O)OC(C)C.C1CCOC1',
#     'precursors': 'Oc1ccc(Cl)cc1-c1cccc(Br)c1',
#     'probability': 0.1,
#     'temperature': 97.5510482788086,
#     'yield': 60.89432144165039},
#    'Oc1ccc(Cl)cc1-c1cccc(Br)c1': {'reagents': 'O=C([O-])[O-].[Na+].[Na+].c1ccc([P](c2ccccc2)(c2ccccc2)[Pd]([P](c2ccccc2)(c2ccccc2)c2ccccc2)([P](c2ccccc2)(c2ccccc2)c2ccccc2)[P](c2ccccc2)(c2ccccc2)c2ccccc2)cc1.COCCOC',
#     'precursors': 'OB(O)c1cccc(Br)c1.Oc1ccc(Cl)cc1I',
#     'probability': 1.0,
#     'temperature': 97.54662322998047,
#     'yield': 65.69876861572266}}]}

# %%
planner.save_to_file(ans)

# %%
for i in range(len(tasklist)):
    print(i,'retro synthesis started',flush=True)
    task = tasklist[i:i+1]
    ans = planner.plan(task)
    planner.save_to_file(ans)
